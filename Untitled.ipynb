# %%
import xarray as xr
b = xr.open_dataset("~/Downloads/ocean_hgrid.nc")

# %%
b
# Out:
# <xarray.Dataset>
# Dimensions:   (nx: 1440, nxp: 1441, ny: 1152, nyp: 1153)
# Dimensions without coordinates: nx, nxp, ny, nyp
# Data variables:
#     tile      |S255 ...
#     y         (nyp, nxp) float64 ...
#     x         (nyp, nxp) float64 ...
#     dy        (ny, nxp) float64 ...
#     dx        (nyp, nx) float64 ...
#     area      (ny, nx) float64 ...
#     angle_dx  (nyp, nxp) float64 ...

# %%
b.x.plot()

# %%
b.y.plot()

# %%
b.area.plot()
