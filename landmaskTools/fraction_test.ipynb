# %% [markdown]
# # Landmask Testing
#
# We need to figure out a way to calculate fraction of cell that is water vs land. For this, we'll need a higher resolution landmask file so we can take the intersection of that within the coarser grid

# %%
import xarray as xr

bathy = xr.open_dataset("/Users/james/Downloads/bathy.nc")

# %%
bathy
# Out:
# <xarray.Dataset>
# Dimensions:    (x: 41, y: 61)
# Coordinates:
#     lon        (y, x) float64 ...
#     lat        (y, x) float64 ...
# Dimensions without coordinates: x, y
# Data variables:
#     elevation  (y, x) float64 ...

# %%
bathy['elevation'].plot()

# %%
bathy = bathy.where(bathy.elevation < 0, 0)
bathy.elevation.plot()
