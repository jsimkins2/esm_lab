# %%
# conda: holo37 xesmfTools

# This should be the minimalist
# notebook script to launch the
# interactive grid toolset.

# The application boilerplate can be
# edited via lib/app.py.  You need to save
# any changes and re-run all the cells for
# changes to be applied.

# Required to manipulate sys.path and access environment
# variables via os.environ.
import os, sys

useDisplay = False
if (os.environ.get('LIBROOT')):
    sys.path.append(os.environ.get('LIBROOT'))
else:
    # Detect use of this notebook in mybinder.org
    # useDisplay if mybinder.org is detected
    cDir = os.getcwd()
    if cDir == '/home/jovyan/gridTools':
        sys.path.append('/home/jovyan/gridTools/lib')
        useDisplay = True
        
# Set your username if you need to use display() instead of show()
if os.environ.get('USER') == 'cermak':
    useDisplay = True

from gridutils import GridUtils
import warnings

# %%
# Disable annoying warnings from python
warnings.filterwarnings('ignore')

# %%
# If we are successful, we can initialize the grid toolset
grd = GridUtils()

# %%
# Initialize the application
dashboard = grd.app()

# %%
# Launch the application

# %%
if not(useDisplay):
    dashboard.show()

# %%
if useDisplay:
    dashboard.servable();

# %%
if useDisplay:
    # Need to expand width of cells in Binder
    from IPython.core.display import HTML
    display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
if useDisplay:
    display(dashboard)
# Out:
# WidgetBox
#     [0] Column(sizing_mode='stretch_width', width_policy='max')
#         [0] TextAreaInput(background='skyblue', height=100, name='Information', value='GridUtils attached t...)
#     [1] Row
#         [0] Tabs
#             [0] Tabs
#                 [0] WidgetBox
#                     [0] Markdown(str)
#                     [1] Select(name='Projection', options=['Nearside Perspective', ...], value='Nearside Perspective')
#                     [2] FloatInput(end=360.0, name='Central Longitude(lon_0) ..., start=0.0, step=1.0, value=230.0, value_throttled=230.0, width=100)
#                     [3] FloatInput(end=90.0, name='Central Latitude(lat_0) (..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [4] FloatInput(end=90.0, name='First Parallel(lat_1) (..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [5] FloatInput(end=90.0, name='Second Parallel(lat_2) (..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [6] FloatInput(end=90.0, name='Latitude of T..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [7] Button(button_type='primary', name='Plot')
#                 [1] WidgetBox
#                     [0] Markdown(str)
#                     [1] FloatInput(end=180.0, name='Longitude(x0) (..., start=-180.0, step=1.0, value=-160.0, value_throttled=-160.0, width=100)
#                     [2] FloatInput(end=180.0, name='Longitude(x1) (..., start=-180.0, step=1.0, value=-100.0, value_throttled=-100.0, width=100)
#                     [3] FloatInput(end=90.0, name='Latitude(y0) (..., start=-90.0, step=1.0, value=20.0, value_throttled=20.0, width=100)
#                     [4] FloatInput(end=90.0, name='Latitude(y1) (..., start=-90.0, step=1.0, value=60.0, value_throttled=60.0, width=100)
#                     [5] Checkbox(name='Use global extent (...)
#                 [2] WidgetBox
#                     [0] Markdown(str)
#                     [1] TextInput(name='Plot title', width=250)
#                     [2] Select(name='Grid Style', options=['Grid Extent', ...], value='Grid Cells')
#                     [3] Select(name='x Color', options=['Blue', 'Cyan', ...], value='Black')
#                     [4] Select(name='y Color', options=['Blue', 'Cyan', ...], value='Black')
#                     [5] FloatInput(end=10.0, name='x Line Width', start=0.01, value=1.0, value_throttled=1.0, width=80)
#                     [6] FloatInput(end=10.0, name='y Line Width', start=0.01, value=1.0, value_throttled=1.0, width=80)
#             [1] Tabs
#                 [0] WidgetBox
#                     [0] Markdown(str)
#                     [1] Select(name='Projection', options=['Mercator', 'Lambert Conf...], value='Lambert Conformal Conic')
#                     [2] FloatInput(end=360.0, name='Central Longitude(lon_0) ..., start=0.0, step=1.0, value=230.0, value_throttled=230.0, width=100)
#                     [3] FloatInput(end=90.0, name='Central Latitude(lat_0) (..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [4] FloatInput(end=90.0, name='First Parallel(lat_1) (..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [5] FloatInput(end=90.0, name='Second Parallel(lat_2) (..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [6] FloatInput(end=90.0, name='Latitude of T..., start=-90.0, step=1.0, value=40.0, value_throttled=40.0, width=100)
#                     [7] FloatInput(end=90.0, name='Tilt (-90 to 90)', start=-90.0, value=30.0, value_throttled=30.0, width=100)
#                     [8] Button(button_type='primary', name='Make Grid')
#                 [1] WidgetBox
#                     [0] Markdown(str)
#                     [1] IntInput(end=100, name='dx', start=0, value=20, value_throttled=20, width=100)
#                     [2] IntInput(end=100, name='dy', start=0, value=30, value_throttled=30, width=100)
#                     [3] FloatInput(end=10.0, name='Grid Resolution', start=0.0, value=1.0, value_throttled=1.0, width=80)
#                     [4] Select(name='Units', options=['degrees', 'meters'], value='degrees')
#                     [5] Button(button_type='primary', name='Make Grid')
#                 [2] WidgetBox
#                     [0] Markdown(str)
#                     [1] Select(name='X grid mode', options=['Left', 'Center', ...], value='Center')
#                     [2] Select(name='Y grid mode', options=['Lower', 'Center', ...], value='Center')
#                     [3] Markdown(str)
#                     [4] Select(disabled=True, name='Grid Type', options=['MOM6'], value='MOM6')
#                     [5] Markdown(str)
#                     [6] IntInput(disabled=True, end=2, name='Grid Mode', start=1, value=2, value_throttled=2, width=80)
#         [1] Tabs
#             [0] Matplotlib(Figure, height=600, sizing_mode='fixed', width=800)
#             [1] Column(width=800)
#                 [0] HTML(Dataset)
#             [2] WidgetBox
#                 [0] Markdown(str)
#                 [1] Markdown(str)
#                 [2] FileInput(accept='.nc')
#                 [3] Button(button_type='primary', name='Load Local Grid')
#                 [4] Markdown(str)
#                 [5] TextInput(name='Grid filename', value='gridFile.nc', width=200)
#                 [6] FileDownload(button_type='success', callback=<bound method A..., filename='gridFile.nc', label='Download Grid')
#             [3] WidgetBox
#                 [0] Button(button_type='primary', name='Load Remote Grid')
#                 [1] TextInput(name='Grid filename', value='gridFile.nc', width=200)
#                 [2] Button(button_type='success', name='Save Remote Grid')
#                 [3] Markdown(str)
#                 [4] FileSelector(directory='/home/cermak', file_pattern='*.nc')
#             [4] Tabs
#                 [0] WidgetBox(width=800)
#                     [0] Markdown(str)
#                 [1] WidgetBox(width=800)
#                     [0] Markdown(str)
