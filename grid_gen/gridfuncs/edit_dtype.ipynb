# %%
import xarray as xr 

# v2 - southern boundary at 5 North - this looks like the winner
latMinInd = 860
latMaxInd = 2550
lonMinInd = 0
lonMaxInd = 1550

land = xr.open_dataset("/Users/james/Documents/Github/esm_lab/grid_gen/gridInfo/chassxu/09m11/land_mask.nc")
subland = land.isel(ny=slice(int(latMinInd/2), int(latMaxInd/2)), nx=slice(int(lonMinInd/2),int(lonMaxInd/2)))

# %%
subland.mask.plot()

# %%
subland["mask"] = subland.mask.astype('double')

# %%
subland.to_netcdf("/Users/james/Downloads/test.nc")

# %%
b = xr.open_dataset("/Users/james/Documents/Github/esm_lab/grid_gen/gridInfo/nwa25/grid_spec.nc")

# %%
b
# Out:
# <xarray.Dataset>
# Dimensions:          (nfile_aXl: 1, nfile_aXo: 1, nfile_lXo: 1)
# Dimensions without coordinates: nfile_aXl, nfile_aXo, nfile_lXo
# Data variables: (12/14)
#     atm_mosaic_dir   |S255 ...
#     atm_mosaic_file  |S255 ...
#     atm_mosaic       |S255 ...
#     lnd_mosaic_dir   |S255 ...
#     lnd_mosaic_file  |S255 ...
#     lnd_mosaic       |S255 ...
#     ...               ...
#     ocn_mosaic       |S255 ...
#     ocn_topog_dir    |S255 ...
#     ocn_topog_file   |S255 ...
#     aXo_file         (nfile_aXo) |S255 ...
#     aXl_file         (nfile_aXl) |S255 ...
#     lXo_file         (nfile_lXo) |S255 ...
# Attributes:
#     grid_version:  0.2
#     code_version:  $Name:  $
#     history:       make_quick_mosaic --input_mosaic ocean_mosaic.nc --mosaic_...

# %%
b.ocn_topog_file
# Out:
# <xarray.DataArray 'ocn_topog_file' ()>
# array(b'ocean_topog.nc', dtype='|S255')

# %%
b.ocn_mosaic_file
# Out:
# <xarray.DataArray 'ocn_mosaic_file' ()>
# array(b'ocean_mosaic.nc', dtype='|S255')
# Attributes:
#     standard_name:  ocean_mosaic_file_name

# %%
b['atm_mosaic_file'] = 'ocean_mosaic.nc'

# %%
b['atm_mosaic_file']
# Out:
# <xarray.DataArray 'atm_mosaic_file' ()>
# array('ocean_mosaic.nc', dtype='<U15')
