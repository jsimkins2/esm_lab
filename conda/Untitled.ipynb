# %%
import xarray as xr

ds = xr.open_dataset("/Users/james/Documents/Github/esm_lab/nep7_grid/atmos_mosaic_tile1Xland_mosaic_tile1.nc")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (ncells: 73371, two: 2)
# Dimensions without coordinates: ncells, two
# Data variables:
#     contact         |S255 ...
#     tile1_cell      (ncells, two) int32 ...
#     tile2_cell      (ncells, two) int32 ...
#     xgrid_area      (ncells) float64 ...
#     tile1_distance  (ncells, two) float64 ...
#     tile2_distance  (ncells, two) float64 ...
# Attributes:
#     grid_version:  0.2
#     code_version:  ESMG/PyCNAL: heads/python3-0-gb0204bf2e5-dirty
#     history:       2020-06-30: convert_ROMS_grid_to_MOM6.py /import/AKWATERS/...

# %%
ds.tile1_cell.plot()

# %%
ds.tile2_cell.plot()
